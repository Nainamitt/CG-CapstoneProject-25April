# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/sales_data.csv")
df.head()
# Out:
#    Product_ID        Date Region  Sales
# 0         101  2025-01-01  North    250
# 1         102  2025-01-02  South    180
# 2         103  2025-01-03   East    210
# 3         101  2025-01-04  North    290
# 4         102  2025-01-05  South    175

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product_ID  9 non-null      int64
#  1   Date        9 non-null      object
#  2   Region      9 non-null      object
#  3   Sales       9 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 420.0+ bytes
#        Product_ID       Sales
# count    9.000000    9.000000
# mean   102.000000  231.666667
# std      0.866025   46.502688
# min    101.000000  175.000000
# 25%    101.000000  200.000000
# 50%    102.000000  230.000000
# 75%    103.000000  250.000000
# max    103.000000  310.000000

# %%
df["Sales"].plot(figsize=(8,4), title="Sales Trend")
plt.show()

# %%
df.groupby("Region")["Sales"].mean()
# Out:
# Region
# East     226.666667
# North    283.333333
# South    185.000000
# Name: Sales, dtype: float64

# %%
df.isnull().sum()
# Out:
# Product_ID    0
# Date          0
# Region        0
# Sales         0
# dtype: int64

# %%
df.groupby("Product_ID")["Sales"].sum()
# Out:
# Product_ID
# 101    850
# 102    555
# 103    680
# Name: Sales, dtype: int64
